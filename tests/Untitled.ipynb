# %%
from ultralytics import YOLO

# %%
model = YOLO("../yolo_v12_rd_dmg_best.pt")

# %%
model.export(format="engine")
# Out:
# WARNING ⚠️ TensorRT requires GPU export, automatically assigning device=0
# Ultralytics 8.3.202 🚀 Python-3.11.13 torch-2.0.1.post2 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 15940MiB)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLOv12n summary (fused): 159 layers, 2,558,093 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '../yolo_v12_rd_dmg_best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 11, 8400) (5.3 MB)
# requirements: Ultralytics requirements ['onnxslim>=0.1.67', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/283.2 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/283.2 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/283.2 MB 2.4 MB/s eta 0:01:59
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/283.2 MB 3.8 MB/s eta 0:01:14
# ...
